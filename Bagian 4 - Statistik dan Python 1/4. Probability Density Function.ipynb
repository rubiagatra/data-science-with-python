# %% [markdown]
#     - Sebuah kuantitas yang bernilai apapun tidak hanya bernilai diskrit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('michelson_speed_of_light.csv')

# %%
samples_std1 = np.random.normal(20, 1, size=100000)
samples_std3 = np.random.normal(20, 3, size=100000)
samples_std10 = np.random.normal(20, 10, size=100000)

# %%
sns.kdeplot(samples_std1)
sns.kdeplot(samples_std3)
sns.kdeplot(samples_std10)

# %%
sns.kdeplot(samples_std3)

# %%
import dc_stat_think as dcst
x_std1, y_std1 = dcst.ecdf(samples_std1)
x_std3, y_std3 = dcst.ecdf(samples_std3)
x_std10, y_std10 = dcst.ecdf(samples_std10)
plt.plot(x_std1, y_std1, marker='.', linestyle='none')
plt.plot(x_std3, y_std3, marker='.', linestyle='none')
plt.plot(x_std10, y_std10, marker='.', linestyle='none')
plt.margins(0.02)
plt.legend(('std = 1', 'std = 3', 'std = 10'), loc='lower right')

# %% [markdown]
# # Normal Distribution

# %%
mean = np.mean(df['velocity of light in air (km/s)'])
std = np.std(df['velocity of light in air (km/s)'])
samples = np.random.normal(mean, std, size=10000)
x, y = dcst.ecdf(df['velocity of light in air (km/s)'])
x_theor, y_theor = dcst.ecdf(samples)
plt.plot(x_theor, y_theor)
plt.plot(x, y, marker='.', linestyle='none')
plt.xlabel('Kecepatan cahaya (km/s)')
plt.ylabel('CDF')
# Out:
# Text(0,0.5,'CDF')

# %%
belmont_no_outliers = [ 148.51,  146.65,  148.52,  150.7 ,  150.42,  150.88,  151.57,
        147.54,  149.65,  148.74,  147.86,  148.75,  147.5 ,  148.26,
        149.71,  146.56,  151.19,  147.88,  149.16,  148.82,  148.96,
        152.02,  146.82,  149.97,  146.13,  148.1 ,  147.2 ,  146.  ,
        146.4 ,  148.2 ,  149.8 ,  147.  ,  147.2 ,  147.8 ,  148.2 ,
        149.  ,  149.8 ,  148.6 ,  146.8 ,  149.6 ,  149.  ,  148.2 ,
        149.2 ,  148.  ,  150.4 ,  148.8 ,  147.2 ,  148.8 ,  149.6 ,
        148.4 ,  148.4 ,  150.2 ,  148.8 ,  149.2 ,  149.2 ,  148.4 ,
        150.2 ,  146.6 ,  149.8 ,  149.  ,  150.8 ,  148.6 ,  150.2 ,
        149.  ,  148.6 ,  150.2 ,  148.2 ,  149.4 ,  150.8 ,  150.2 ,
        152.2 ,  148.2 ,  149.2 ,  151.  ,  149.6 ,  149.6 ,  149.4 ,
        148.6 ,  150.  ,  150.6 ,  149.2 ,  152.6 ,  152.8 ,  149.6 ,
        151.6 ,  152.8 ,  153.2 ,  152.4 ,  152.2 ]

# %%
mu = np.mean(belmont_no_outliers)
sigma = np.std(belmont_no_outliers)
samples = np.random.normal(mu, sigma, size=10000)
x_theor, y_theor = dcst.ecdf(samples)
x, y = dcst.ecdf(belmont_no_outliers)
plt.plot(x_theor, y_theor)
plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.02)
plt.xlabel('Belmont winning time (sec.)')
plt.ylabel('CDF')
# Out:
# Text(0,0.5,'CDF')

# %%
samples = np.random.normal(mu, sigma, size=1000000)
prob = sum(samples <= 144) / len(samples)
print('Probability of besting Secretariat:', prob)
# Out:
# Probability of besting Secretariat: 0.000619

# %% [markdown]
# # Exponential

# %%
def successive_poisson(tau1, tau2, size=1):
    t1 = np.random.exponential(tau1, size)
    t2 = np.random.exponential(tau2, size)

    return t1 + t2

# %%
waiting_times = successive_poisson(764, 715, size=100000)

plt.hist(waiting_times, normed=True, histtype='step', bins=100)

plt.xlabel('Waiting Times')
plt.ylabel('Y')
# Out:
# Text(0,0.5,'Y')
