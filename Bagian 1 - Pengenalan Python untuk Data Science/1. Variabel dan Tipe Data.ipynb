# %% [markdown]
# # Python Dasar

# %% [markdown]
# ## 1. Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## 2. Variabel
# ### - Spesifik, *case sensitive* ,  dan dapat dipanggil melalui nama variabel

# %%
tinggi = 1.65
berat = 55

# %%
tinggi
# Out:
# 172

# %%
berat
# Out:
# 85

# %% [markdown]
# Menghitung BMI atau *Body Mass Index*  dapat kita gunakan persamaan berikut $BMI = \frac{Berat}{Tinggi^2}$

# %%
tinggi = 1.78 # Meter
berat = 70 # Kilogram

# %%
70 / 1.78 ** 2
# Out:
# 22.093170054286073

# %%
berat / tinggi ** 2
# Out:
# 22.093170054286073

# %%
bmi
# Out:
# 22.093170054286073

# %% [markdown]
# ### *Reproducibility*

# %%
tinggi = 1.68
berat = 85 # Coba ganti berat dengan angka yang lain apa yang terjadi?
bmi = berat / tinggi ** 2
print(bmi)
# Out:
# 30.116213151927443

# %% [markdown]
# ## Tipe Data

# %%
type(bmi)
# Out:
# float

# %%
jumlah_hari = 7

# %%
type(jumlah_hari)
# Out:
# int

# %%
x = 'BMI itu apa?'
y = 'Haha'

# %%
print(type(x), type(y))
# Out:
# <class 'str'> <class 'str'>

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
z = True
type(z)
# Out:
# bool
